# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# 2025-08-13 13:18:30.592990: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-13 13:18:30.786672: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755071310.873012    2784 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755071310.899311    2784 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
img1_path="../debug_faces/Krishna_angle1.jpg"
img2_path="../debug_faces/abcd.jpg"
model_name = "ArcFace"
detector_backend="retinaface"

# %%
img1 = DeepFace.extract_faces(img1_path)
img2 = DeepFace.extract_faces(img2_path)

# %%
img1
# Out:
# [{'face': array([[[0.16470588, 0.13333333, 0.18039216],
#           [0.16078431, 0.13333333, 0.17254902],
#           [0.15686275, 0.12941176, 0.17254902],
#           ...,
#           [0.14901961, 0.1254902 , 0.16470588],
#           [0.14117647, 0.11764706, 0.15686275],
#           [0.14117647, 0.11764706, 0.15686275]],
#
#          [[0.15686275, 0.1254902 , 0.16862745],
#           [0.16078431, 0.12941176, 0.17254902],
#           [0.15294118, 0.12941176, 0.16862745],
#           ...,
#           [0.14509804, 0.12156863, 0.15686275],
#           [0.1372549 , 0.11764706, 0.14509804],
#           [0.14117647, 0.11372549, 0.15294118]],
#
#          [[0.15294118, 0.12156863, 0.16862745],
#           [0.15686275, 0.12156863, 0.16470588],
#           [0.15686275, 0.12941176, 0.16862745],
#           ...,
#           [0.16078431, 0.13333333, 0.16862745],
#           [0.14509804, 0.12941176, 0.15294118],
#           [0.14901961, 0.12156863, 0.15686275]],
#
#          ...,
#
# ...

# %%
embeddings= DeepFace.represent(img_path=img1_path,model_name=model_name,detector_backend=detector_backend)

# %%
embeddings
# Out:
# [{'embedding': [0.10328365117311478,
#    0.23476721346378326,
#    0.23483780026435852,
#    -0.2764074206352234,
#    0.39300617575645447,
#    0.0345839187502861,
#    -0.14570243656635284,
#    0.062462348490953445,
#    0.004586957395076752,
#    -0.15406888723373413,
#    -0.2368820607662201,
#    -0.08282899856567383,
#    0.008738914504647255,
#    0.17988191545009613,
#    -0.025079792365431786,
#    0.0293183084577322,
#    0.04195461794734001,
#    0.03994259238243103,
#    -0.2427881807088852,
#    0.07780398428440094,
#    0.27102264761924744,
#    -0.08541299402713776,
#    -0.13744506239891052,
#    -0.037906043231487274,
#    0.1810143142938614,
#    -0.07620565593242645,
#    -0.27501732110977173,
#    0.18042325973510742,
#    0.019062820822000504,
#    0.138916015625,
#    -0.20380473136901855,
#    0.2627792954444885,
#    -0.053810663521289825,
#    -0.33411934971809387,
#    -0.09058067202568054,
#    0.11470801383256912,
#    -0.15625494718551636,
# ...

# %%
plt.imshow(img1[0]["face"])

# %%
plt.imshow(img2[0]["face"])

# %%
resp = DeepFace.verify(img1_path=img1_path,img2_path=img2_path,model_name=model_name,detector_backend=detector_backend)

# %%
resp
# Out:
# {'verified': True,
#  'distance': 0.384328,
#  'threshold': 0.68,
#  'confidence': 74.83,
#  'model': 'ArcFace',
#  'detector_backend': 'retinaface',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 149,
#    'y': 147,
#    'w': 188,
#    'h': 246,
#    'left_eye': (284, 239),
#    'right_eye': (193, 239),
#    'nose': (234, 292),
#    'mouth_left': (272, 337),
#    'mouth_right': (205, 336)},
#   'img2': {'x': 126,
#    'y': 129,
#    'w': 229,
#    'h': 293,
#    'left_eye': (289, 241),
#    'right_eye': (180, 240),
#    'nose': (230, 308),
#    'mouth_left': (274, 356),
#    'mouth_right': (192, 355)}},
#  'time': 8.78}
